# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
import seaborn as sns

# %%
import zipfile

# %%
## If you are using the data by mounting the google drive, use the following :
from google.colab import drive
drive.mount('/content/gdrive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166
# Out:
# Mounted at /content/gdrive

# %%
with zipfile.ZipFile('/content/gdrive/MyDrive/Colab Notebooks/CNN_assignment.zip', 'r') as zip_ref:
    zip_ref.extractall('.')

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path("/content/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
data_dir_test = pathlib.Path('/content/Skin cancer ISIC The International Skin Imaging Collaboration/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.utils.image_dataset_from_directory(data_dir_train,
                                                       shuffle=True,
                                                       batch_size=batch_size,
                                                       image_size=(img_height,img_width),
                                                       validation_split = 0.2,
                                                       subset='training',
                                                       seed=123)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.utils.image_dataset_from_directory(data_dir_train,
                                                     shuffle=True,
                                                     batch_size=batch_size,
                                                     image_size=(img_height,img_width),
                                                     validation_split = 0.2,
                                                     subset='validation',
                                                     seed=123)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list.
# You can find the class names in the class_names attribute on these datasets.
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
print(len(class_names))
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']
# 9

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
for i in range(9):
  ax = plt.subplot(3, 3, i + 1)
  image = plt.imread(str(list(data_dir_train.glob(class_names[i]+'/*.jpg'))[1]))
  plt.title(class_names[i])
  plt.imshow(image)

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
### Your code goes here
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential()

model.add(layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3)))

model.add(Conv2D(32,kernel_size=(3,3),activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(64,kernel_size=(3,3),activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(128,kernel_size=(3,3),activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(256,kernel_size=(11,11),activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(64,activation='relu'))

model.add(Dense(len(class_names),activation='softmax'))

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 178, 178, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 89, 89, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 41, 41, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 20, 20, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 10, 10, 256)       3965184
#
#  max_pooling2d_3 (MaxPooling  (None, 5, 5, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 6400)              0
#
#  dense (Dense)               (None, 64)                409664
#
#  dense_1 (Dense)             (None, 9)                 585
#
# =================================================================
# Total params: 4,468,681
# Trainable params: 4,468,681
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 25s 111ms/step - loss: 2.0765 - accuracy: 0.2031 - val_loss: 1.9920 - val_accuracy: 0.2260
# Epoch 2/20
# 56/56 [==============================] - 2s 44ms/step - loss: 1.8435 - accuracy: 0.3013 - val_loss: 1.6945 - val_accuracy: 0.3870
# Epoch 3/20
# 56/56 [==============================] - 2s 44ms/step - loss: 1.6701 - accuracy: 0.3728 - val_loss: 1.5262 - val_accuracy: 0.4318
# Epoch 4/20
# 56/56 [==============================] - 3s 47ms/step - loss: 1.5215 - accuracy: 0.4570 - val_loss: 1.4964 - val_accuracy: 0.4966
# Epoch 5/20
# 56/56 [==============================] - 3s 47ms/step - loss: 1.4674 - accuracy: 0.4794 - val_loss: 1.3841 - val_accuracy: 0.4944
# Epoch 6/20
# 56/56 [==============================] - 2s 45ms/step - loss: 1.4237 - accuracy: 0.5106 - val_loss: 1.3651 - val_accuracy: 0.5414
# Epoch 7/20
# 56/56 [==============================] - 3s 47ms/step - loss: 1.3791 - accuracy: 0.5145 - val_loss: 1.3617 - val_accuracy: 0.5168
# Epoch 8/20
# 56/56 [==============================] - 3s 48ms/step - loss: 1.3395 - accuracy: 0.5301 - val_loss: 1.4205 - val_accuracy: 0.5235
# Epoch 9/20
# 56/56 [==============================] - 3s 46ms/step - loss: 1.2730 - accuracy: 0.5485 - val_loss: 1.3539 - val_accuracy: 0.5190
# Epoch 10/20
# 56/56 [==============================] - 2s 44ms/step - loss: 1.2884 - accuracy: 0.5485 - val_loss: 1.3258 - val_accuracy: 0.5347
# Epoch 11/20
# 56/56 [==============================] - 2s 44ms/step - loss: 1.2178 - accuracy: 0.5653 - val_loss: 1.3584 - val_accuracy: 0.5302
# Epoch 12/20
# 56/56 [==============================] - 2s 44ms/step - loss: 1.1722 - accuracy: 0.5848 - val_loss: 1.4358 - val_accuracy: 0.5056
# Epoch 13/20
# 56/56 [==============================] - 3s 47ms/step - loss: 1.1587 - accuracy: 0.5876 - val_loss: 1.4288 - val_accuracy: 0.4989
# Epoch 14/20
# 56/56 [==============================] - 3s 45ms/step - loss: 1.1092 - accuracy: 0.5971 - val_loss: 1.3936 - val_accuracy: 0.5011
# Epoch 15/20
# 56/56 [==============================] - 2s 44ms/step - loss: 1.0541 - accuracy: 0.6144 - val_loss: 1.3831 - val_accuracy: 0.5481
# Epoch 16/20
# 56/56 [==============================] - 2s 44ms/step - loss: 1.0323 - accuracy: 0.6317 - val_loss: 1.5962 - val_accuracy: 0.5034
# Epoch 17/20
# 56/56 [==============================] - 3s 45ms/step - loss: 0.9856 - accuracy: 0.6523 - val_loss: 1.4359 - val_accuracy: 0.5526
# Epoch 18/20
# 56/56 [==============================] - 3s 45ms/step - loss: 0.9086 - accuracy: 0.6691 - val_loss: 1.4668 - val_accuracy: 0.5280
# Epoch 19/20
# 56/56 [==============================] - 2s 43ms/step - loss: 0.9558 - accuracy: 0.6529 - val_loss: 1.5502 - val_accuracy: 0.5302
# Epoch 20/20
# 56/56 [==============================] - 2s 43ms/step - loss: 0.8388 - accuracy: 0.6998 - val_loss: 1.5596 - val_accuracy: 0.5347

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(16, 6))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# ## Findings:
# 1. The model clearly overfits i.e. the Training Accuracy is 70% and the validation accuracy is around 53%.
# 2. The trainng loss also decreases with increase in Epochs however the validation loss is on the higher side.
#
# This concludes that the model is not suitable for predictions and need to implemenment some techniques to handle the overfitting.

# %% [markdown]
# ### Write your findings here

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy.
# Your code goes here
data_augmentation = tf.keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical",
                                                 input_shape=(img_height,
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.2),
    layers.experimental.preprocessing.RandomContrast(0.1)
  ]
)

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
# Your code goes here
plt.figure(figsize=(12, 12))
for images, labels in train_ds.take(1):
    for i in range(9):
      augmented_images = data_augmentation(images)
      ax = plt.subplot(3, 3, i + 1)
      plt.imshow(augmented_images[0].numpy().astype("uint8"))
      plt.axis("off")

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

## Your code goes here
model = Sequential()

model.add(layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3)))
model.add(data_augmentation)

model.add(Conv2D(32,kernel_size=(3,3),activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(64,kernel_size=(3,3),activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(128,kernel_size=(3,3),activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(256,kernel_size=(11,11),activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.25))

model.add(Dense(len(class_names),activation='softmax'))

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  conv2d_8 (Conv2D)           (None, 178, 178, 32)      896
#
#  max_pooling2d_8 (MaxPooling  (None, 89, 89, 32)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_9 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 41, 41, 128)       73856
#
#  max_pooling2d_10 (MaxPoolin  (None, 20, 20, 128)      0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 10, 10, 256)       3965184
#
#  max_pooling2d_11 (MaxPoolin  (None, 5, 5, 256)        0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 5, 5, 256)         0
#
#  flatten_2 (Flatten)         (None, 6400)              0
#
#  dense_4 (Dense)             (None, 64)                409664
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 9)                 585
#
# =================================================================
# Total params: 4,468,681
# Trainable params: 4,468,681
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 7s 75ms/step - loss: 2.0640 - accuracy: 0.2026 - val_loss: 1.9262 - val_accuracy: 0.2931
# Epoch 2/20
# 56/56 [==============================] - 4s 69ms/step - loss: 1.9615 - accuracy: 0.2612 - val_loss: 1.8673 - val_accuracy: 0.3490
# Epoch 3/20
# 56/56 [==============================] - 4s 67ms/step - loss: 1.8673 - accuracy: 0.3019 - val_loss: 1.7536 - val_accuracy: 0.3848
# Epoch 4/20
# 56/56 [==============================] - 4s 67ms/step - loss: 1.7725 - accuracy: 0.3382 - val_loss: 1.8255 - val_accuracy: 0.3311
# Epoch 5/20
# 56/56 [==============================] - 4s 69ms/step - loss: 1.6812 - accuracy: 0.3834 - val_loss: 1.7059 - val_accuracy: 0.4161
# Epoch 6/20
# 56/56 [==============================] - 4s 68ms/step - loss: 1.6160 - accuracy: 0.4319 - val_loss: 1.5037 - val_accuracy: 0.4832
# Epoch 7/20
# 56/56 [==============================] - 4s 66ms/step - loss: 1.5393 - accuracy: 0.4369 - val_loss: 1.5104 - val_accuracy: 0.4899
# Epoch 8/20
# 56/56 [==============================] - 4s 66ms/step - loss: 1.5049 - accuracy: 0.4777 - val_loss: 1.5355 - val_accuracy: 0.4609
# Epoch 9/20
# 56/56 [==============================] - 4s 70ms/step - loss: 1.5389 - accuracy: 0.4721 - val_loss: 1.5409 - val_accuracy: 0.4452
# Epoch 10/20
# 56/56 [==============================] - 4s 67ms/step - loss: 1.4583 - accuracy: 0.4972 - val_loss: 1.3705 - val_accuracy: 0.5280
# Epoch 11/20
# 56/56 [==============================] - 4s 66ms/step - loss: 1.4325 - accuracy: 0.4961 - val_loss: 1.4521 - val_accuracy: 0.4899
# Epoch 12/20
# 56/56 [==============================] - 4s 66ms/step - loss: 1.4421 - accuracy: 0.4872 - val_loss: 1.3820 - val_accuracy: 0.5190
# Epoch 13/20
# 56/56 [==============================] - 4s 70ms/step - loss: 1.4108 - accuracy: 0.5061 - val_loss: 1.4191 - val_accuracy: 0.5078
# Epoch 14/20
# 56/56 [==============================] - 4s 66ms/step - loss: 1.3978 - accuracy: 0.5084 - val_loss: 1.3726 - val_accuracy: 0.5235
# Epoch 15/20
# 56/56 [==============================] - 4s 65ms/step - loss: 1.3970 - accuracy: 0.5100 - val_loss: 1.4719 - val_accuracy: 0.4877
# Epoch 16/20
# 56/56 [==============================] - 4s 69ms/step - loss: 1.4241 - accuracy: 0.5134 - val_loss: 1.4214 - val_accuracy: 0.5078
# Epoch 17/20
# 56/56 [==============================] - 4s 66ms/step - loss: 1.3741 - accuracy: 0.5033 - val_loss: 1.3522 - val_accuracy: 0.5235
# Epoch 18/20
# 56/56 [==============================] - 4s 65ms/step - loss: 1.3523 - accuracy: 0.5268 - val_loss: 1.3167 - val_accuracy: 0.5414
# Epoch 19/20
# 56/56 [==============================] - 4s 70ms/step - loss: 1.3768 - accuracy: 0.5128 - val_loss: 1.3889 - val_accuracy: 0.5257
# Epoch 20/20
# 56/56 [==============================] - 4s 65ms/step - loss: 1.3681 - accuracy: 0.5100 - val_loss: 1.3734 - val_accuracy: 0.5257

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(16, 6))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?

# %% [markdown]
# We an see that the overfitting has been handled with data augmentation.
# The training accuracy and validation accuracy are similar around 51%.
#
# We can also see that the training and validation losses are decreasing togather which means our model is learning well.
#
#
# **However the overall accuracy is still on the lower side depicting underfitting.**

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.
path_list=[]
lesion_list=[]
for i in class_names:
    for j in data_dir_train.glob(i+'/*.jpg'):
        path_list.append(str(j))
        lesion_list.append(i)
dataframe_dict_original = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
original_df
# Out:
#                                                    Path              Label
# 0     /content/Skin cancer ISIC The International Sk...  actinic keratosis
# 1     /content/Skin cancer ISIC The International Sk...  actinic keratosis
# 2     /content/Skin cancer ISIC The International Sk...  actinic keratosis
# 3     /content/Skin cancer ISIC The International Sk...  actinic keratosis
# 4     /content/Skin cancer ISIC The International Sk...  actinic keratosis
# ...                                                 ...                ...
# 2234  /content/Skin cancer ISIC The International Sk...    vascular lesion
# 2235  /content/Skin cancer ISIC The International Sk...    vascular lesion
# 2236  /content/Skin cancer ISIC The International Sk...    vascular lesion
# 2237  /content/Skin cancer ISIC The International Sk...    vascular lesion
# 2238  /content/Skin cancer ISIC The International Sk...    vascular lesion
#
# [2239 rows x 2 columns]

# %%
# Using seaborn to check for class distribution
ax=sns.countplot(x='Label',data=original_df)
plt.xticks(rotation=90)
plt.show()

# %%
original_df['Label'].value_counts()
# Out:
# pigmented benign keratosis    462
# melanoma                      438
# basal cell carcinoma          376
# nevus                         357
# squamous cell carcinoma       181
# vascular lesion               139
# actinic keratosis             114
# dermatofibroma                 95
# seborrheic keratosis           77
# Name: Label, dtype: int64

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
# #### - **Answer:** seborrheic keratosis has 77 samples which is the least
# #### - Which classes dominate the data in terms proportionate number of samples?
# #### - **Answer:** pigmented benign keratosis with 462 and melanoma with 438 dominate the entire dataset

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Requirement already satisfied: Augmentor in /usr/local/lib/python3.10/dist-packages (0.2.12)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (9.4.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (4.66.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (1.23.5)

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset="/content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i , save_format='jpg')
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7CDB7139DA80>: 100%|██████████| 500/500 [00:20<00:00, 24.40 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7CDBDF2EADA0>: 100%|██████████| 500/500 [00:20<00:00, 23.92 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7CDB7139DA80>: 100%|██████████| 500/500 [00:15<00:00, 31.82 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7CDB46F6EAA0>: 100%|██████████| 500/500 [01:25<00:00,  5.84 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=767x576 at 0x7CDB46C349A0>: 100%|██████████| 500/500 [01:19<00:00,  6.30 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7CDB46CACF40>: 100%|██████████| 500/500 [00:17<00:00, 28.09 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x7CDB46F0C490>: 100%|██████████| 500/500 [00:38<00:00, 12.98 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7CDB46FE11E0>: 100%|██████████| 500/500 [00:15<00:00, 32.32 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7CDB146E36D0>: 100%|██████████| 500/500 [00:15<00:00, 32.26 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
from glob import glob

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
path_list_new = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
path_list_new

# %%
len(path_list_new)
# Out:
# 4500

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
len(lesion_list_new)
# Out:
# 4500

# %%
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = original_df.append(df2)
# Out:
# <ipython-input-47-17a6b079869a>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = original_df.append(df2)

# %%
new_df.head()
# Out:
#                                                 Path              Label
# 0  /content/Skin cancer ISIC The International Sk...  actinic keratosis
# 1  /content/Skin cancer ISIC The International Sk...  actinic keratosis
# 2  /content/Skin cancer ISIC The International Sk...  actinic keratosis
#
50
# 169/169 [==============================] - 33s 190ms/step - loss: 0.4775 - accuracy: 0.8184 - val_loss: 0.5661 - val_accuracy: 0.8278
# Epoch 25/50
# 169/169 [==============================] - 34s 189ms/step - loss: 0.4915 - accuracy: 0.8179 - val_loss: 0.6322 - val_accuracy: 0.7944
# Epoch 26/50
# 169/169 [==============================] - 33s 188ms/step - loss: 0.4167 - accuracy: 0.8442 - val_loss: 0.5799 - val_accuracy: 0.8255
# Epoch 27/50
# 169/169 [==============================] - 32s 186ms/step - loss: 0.4053 - accuracy: 0.8420 - val_loss: 0.5088 - val_accuracy: 0.8411
# Epoch 28/50
# 169/169 [==============================] - 34s 194ms/step - loss: 0.4081 - accuracy: 0.8425 - val_loss: 0.5155 - val_accuracy: 0.8434
# Epoch 29/50
# 169/169 [==============================] - 37s 217ms/step - loss: 0.3636 - accuracy: 0.8581 - val_loss: 0.5466 - val_accuracy: 0.8382
# Epoch 30/50
# 169/169 [==============================] - 32s 186ms/step - loss: 0.3916 - accuracy: 0.8498 - val_loss: 0.5186 - val_accuracy: 0.8434
# Epoch 31/50
# 169/169 [==============================] - 37s 216ms/step - loss: 0.3977 - accuracy: 0.8440 - val_loss: 0.6107 - val_accuracy: 0.8159
# Epoch 32/50
# 169/169 [==============================] - 32s 187ms/step - loss: 0.3738 - accuracy: 0.8583 - val_loss: 0.6549 - val_accuracy: 0.8285
# Epoch 33/50
# 169/169 [==============================] - 33s 190ms/step - loss: 0.3859 - accuracy: 0.8544 - val_loss: 0.4990 - val_accuracy: 0.8411
# Epoch 34/50
# 169/169 [==============================] - 34s 191ms/step - loss: 0.3391 - accuracy: 0.8709 - val_loss: 0.6418 - val_accuracy: 0.8211
# Epoch 35/50
# 169/169 [==============================] - 32s 185ms/step - loss: 0.4012 - accuracy: 0.8600 - val_loss: 0.7086 - val_accuracy: 0.8070
# Epoch 36/50
# 169/169 [==============================] - 33s 188ms/step - loss: 0.3462 - accuracy: 0.8665 - val_loss: 0.5891 - val_accuracy: 0.8411
# Epoch 37/50
# 169/169 [==============================] - 34s 196ms/step - loss: 0.3096 - accuracy: 0.8795 - val_loss: 0.5028 - val_accuracy: 0.8634
# Epoch 38/50
# 169/169 [==============================] - 32s 186ms/step - loss: 0.4651 - accuracy: 0.8344 - val_loss: 0.5627 - val_accuracy: 0.8500
# Epoch 39/50
# 169/169 [==============================] - 32s 185ms/step - loss: 0.2669 - accuracy: 0.8882 - val_loss: 0.4800 - val_accuracy: 0.8797
# Epoch 40/50
# 169/169 [==============================] - 35s 202ms/step - loss: 0.2467 - accuracy: 0.9056 - val_loss: 0.5700 - val_accuracy: 0.8589
# Epoch 41/50
# 169/169 [==============================] - 32s 186ms/step - loss: 0.2780 - accuracy: 0.8909 - val_loss: 0.5699 - val_accuracy: 0.8500
# Epoch 42/50
# 169/169 [==============================] - 32s 187ms/step - loss: 0.2652 - accuracy: 0.8989 - val_loss: 0.4746 - val_accuracy: 0.8790
# Epoch 43/50
# 169/169 [==============================] - 33s 190ms/step - loss: 0.2639 - accuracy: 0.8971 - val_loss: 1.0466 - val_accuracy: 0.7513
# Epoch 44/50
# 169/169 [==============================] - 33s 188ms/step - loss: 0.2890 - accuracy: 0.8867 - val_loss: 0.5418 - val_accuracy: 0.8716
# Epoch 45/50
# 169/169 [==============================] - 32s 186ms/step - loss: 0.3053 - accuracy: 0.8858 - val_loss: 0.4867 - val_accuracy: 0.8723
# Epoch 46/50
# 169/169 [==============================] - 34s 193ms/step - loss: 0.2487 - accuracy: 0.9019 - val_loss: 0.5385 - val_accuracy: 0.8775
# Epoch 47/50
# 169/169 [==============================] - 34s 194ms/step - loss: 0.3205 - accuracy: 0.8761 - val_loss: 0.5324 - val_accuracy: 0.8745
# Epoch 48/50
# 169/169 [==============================] - 37s 216ms/step - loss: 0.3088 - accuracy: 0.8928 - val_loss: 0.6131 - val_accuracy: 0.8634
# Epoch 49/50
# 169/169 [==============================] - 32s 186ms/step - loss: 0.2742 - accuracy: 0.9024 - val_loss: 0.4729 - val_accuracy: 0.8679
# Epoch 50/50
# 169/169 [==============================] - 32s 185ms/step - loss: 0.2571 - accuracy: 0.8971 - val_loss: 0.5873 - val_accuracy: 0.8604

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?

# %% [markdown]
# The CNN model with augmented data for class balancing worked perfectly to overcome both overfitting and underfitting problems that were encountered in previously created 2 models.
#
# The final model gave the accuracy on training as 89% and on vaidation dataset as 86%. Which means the model is a perfect fit.
#
# The loss for both training and validation dataset gradually decreases togather.
